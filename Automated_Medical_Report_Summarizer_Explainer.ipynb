# %% [markdown]
# # Step 1: Set Up the Environment

# %%
# Confirm Colab Pro RAM and GPU
# !free -h
# !nvidia-smi

# Install required libraries
# !pip install transformers datasets peft bitsandbytes torch accelerate rouge_score bert_score

# Mount Google Drive for saving models
from google.colab import drive
drive.mount('/content/drive')
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:            83Gi       965Mi        78Gi       1.0Mi       4.5Gi        81Gi
# Swap:             0B          0B          0B
# Sat Mar 22 19:35:39 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             57W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.49.0)
# Collecting datasets
#   Downloading datasets-3.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.5.2)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.14)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from bert_score) (3.10.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert_score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert_score) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert_score) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert_score) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert_score) (3.2.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.4.2)
# Downloading datasets-3.4.1-py3-none-any.whl (487 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 9.0 MB/s eta 0:00:00
# Downloading bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 23.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.3 MB/s eta 0:00:00
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 5.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.1 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 16.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.4 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 19.8 MB/s eta 0:00:00
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=325c4afb532a66aad92030dde61fa6f9c92e2edc3dafdfd5da08f234b2fecd1d
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# Installing collected packages: xxhash, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fsspec, dill, rouge_score, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, bitsandbytes, bert_score
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed bert_score-0.3.13 bitsandbytes-0.45.3 datasets-3.4.1 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 rouge_score-0.1.2 xxhash-3.5.0
# Mounted at /content/drive

# %%
# Log in to Hugging Face with a read token (since LLaMA 3 8B is gated)
from huggingface_hub import login
login(token="")  # Replace with your read token

# %% [markdown]
# # Step 2: Import Libraries

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments, Trainer, BitsAndBytesConfig
from datasets import load_dataset
from peft import LoraConfig, get_peft_model
from rouge_score import rouge_scorer
from bert_score import score
import re
import os
import pandas as pd
from transformers import pipeline
from rouge_score import rouge_scorer
from bert_score import score as bert_score
import numpy as np

# %% [markdown]
# # Step 3: Load and Preprocess the Dataset

# %%
# Load the full dataset
dataset = load_dataset("omi-health/medical-dialogue-to-soap-summary")
print("Original Training Split Size:", len(dataset["train"]))
print("Original Validation Split Size:", len(dataset["validation"]))
print("Original Test Split Size:", len(dataset["test"]))

# Preprocessing function
def preprocess_dialogue(example):
    dialogue = example["dialogue"]
    soap = example["soap"]

    # Clean text
    dialogue = re.sub(r'[^A-Za-z0-9\s.,:?-]', '', dialogue).lower()
    soap = re.sub(r'[^A-Za-z0-9\s.,:?-]', '', soap).lower()

    # Add role tags
    dialogue = dialogue.replace("Doctor:", "[Doctor]:")
    dialogue = dialogue.replace("Patient:", "[Patient]:")

    return {"dialogue": dialogue, "soap": soap}

# Apply preprocessing
processed_dataset = dataset.map(preprocess_dialogue)
# Out:
# Original Training Split Size: 9250
# Original Validation Split Size: 500
# Original Test Split Size: 250

# %% [markdown]
# # Step 4: Tokenize the Dataset

# %%
# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Meta-Llama-3-8B")

# Set padding token (LLaMA 3 might not have a pad token by default)
tokenizer.pad_token = tokenizer.eos_token

# Tokenization function with labels
def tokenize_function(example):
    tokenized = tokenizer(
        example["text"],
        truncation=True,
        padding="max_length",
        max_length=512,
        return_tensors="pt"
    )
    tokenized["labels"] = tokenized["input_ids"].clone()
    return tokenized

# Apply tokenization
tokenized_dataset = processed_dataset.map(tokenize_function, batched=True)

# Remove unnecessary columns and set format
tokenized_dataset = tokenized_dataset.remove_columns(["dialogue", "soap", "text"])
tokenized_dataset.set_format("torch")

# Split into train and eval datasets
train_dataset = tokenized_dataset["train"]
eval_dataset = tokenized_dataset["validation"]

# Debug: Verify 'labels' key
print("Sample from train_dataset:", train_dataset[0].keys())
print("Sample 'labels' shape:", train_dataset[0]["labels"].shape)
print("Sample from eval_dataset:", eval_dataset[0].keys())
print("Sample 'labels' shape (eval):", eval_dataset[0]["labels"].shape)
# Out:
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Sample from train_dataset: dict_keys(['prompt', 'messages', 'messages_nosystem', 'input_ids', 'attention_mask', 'labels'])
# Sample 'labels' shape: torch.Size([512])
# Sample from eval_dataset: dict_keys(['prompt', 'messages', 'messages_nosystem', 'input_ids', 'attention_mask', 'labels'])
# Sample 'labels' shape (eval): torch.Size([512])

# %% [markdown]
# # Step 5: Load the Model with QLoRA

# %%
# Quantization config for QLoRA
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype="float16"
)

# Load the model
model_name = "meta-llama/Meta-Llama-3-8B"
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=quant_config,
    device_map="auto",
    torch_dtype=torch.float16
)

# LoRA config
lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

# Apply LoRA
model = get_peft_model(model, lora_config)

# Print model to verify
print("Model Loaded with PEFT:", model)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Model Loaded with PEFT: PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %% [markdown]
# # Step 6: Fine-Tune the Model

# %%
# Clear GPU memory
torch.cuda.empty_cache()

# %%
# Set PyTorch memory management
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=5,  # Increased from 3 to 5
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=10,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    report_to="none"
)

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    tokenizer=tokenizer,
)

# Train the model
trainer.train()

# Save the model (optional, for later use)
model.save_pretrained("/content/drive/MyDrive/fine_tuned_model")
tokenizer.save_pretrained("/content/drive/MyDrive/fine_tuned_model")
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1594: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# <ipython-input-40-23cd7dd63cc8>:26: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#     <div>
#
#       <progress value='11565' max='11565' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11565/11565 1:44:52, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.367500</td>
#       <td>1.344921</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.322200</td>
#       <td>1.328012</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.290500</td>
#       <td>1.321401</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.279500</td>
#       <td>1.321004</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.242100</td>
#       <td>1.322907</td>
#     </tr>
#   </tbody>
# </table><p>
# ('/content/drive/MyDrive/fine_tuned_model/tokenizer_config.json',
#  '/content/drive/MyDrive/fine_tuned_model/special_tokens_map.json',
#  '/content/drive/MyDrive/fine_tuned_model/tokenizer.json')

# %% [markdown]
# # Step 7: Clear Memory After Training

# %%
# Clear memory after training
del trainer, model
torch.cuda.empty_cache()

# %% [markdown]
# # Step 8: Load Model for Evaluation

# %%
# Load the quantization config

quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype="float16"
)

# Load the fine-tuned model and tokenizer
model = AutoModelForCausalLM.from_pretrained(
    "/content/drive/MyDrive/fine_tuned_model",
    quantization_config=quant_config,
    device_map="auto",
    torch_dtype=torch.float16
)
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Meta-Llama-3-8B")
tokenizer.pad_token = tokenizer.eos_token

# Load the test split
dataset = load_dataset("omi-health/medical-dialogue-to-soap-summary", split="test")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# # Step 9: Generate Predictions for Evaluation

# %%
# Generate predictions
generated_soaps = []
reference_soaps = []

num_samples = len(dataset)
for i in range(num_samples):
    # Extract the dialogue for this sample
    dialogue_input = dataset[i]["dialogue"]

    # Format the input prompt
    prompt = f"""
You are a medical assistant AI designed to generate SOAP notes (Subjective, Objective, Assessment, and Plan) from medical dialogues.

A SOAP note has four sections:
Subjective (S): Patient's reported symptoms, history, and concerns.
Objective (O): Measurable or observed data (e.g., vitals, exam findings, labs).
Assessment (A): Diagnosis or clinical impression.
Plan (P): Treatment plan (e.g., tests, medications, follow-up).

Now, carefully read the following medical dialogue and create a detailed SOAP note in this format:

Dialogue:
{dialogue_input}

SOAP Note:
"""

    # Use the prompt as the input text
    input_text = prompt

    # Tokenize the input
    inputs = tokenizer(
        input_text,
        return_tensors="pt",
        truncation=True,
        max_length=1024
    ).to("cuda")
    generate_inputs = {
        "input_ids": inputs["input_ids"],
        "attention_mask": inputs["attention_mask"]
    }

    # Generate with adjusted parameters
    outputs = model.generate(
        **generate_inputs,
        max_new_tokens=800,
        pad_token_id=tokenizer.eos_token_id,
        temperature=0.1,  # Reduced for less hallucination
        top_p=0.95,  # Adjusted for more diversity
        repetition_penalty=1.2,
        do_sample=True
    )
    generated_soap = tokenizer.decode(outputs[0], skip_special_tokens=True)

    # Extract the generated SOAP note content
    if "SOAP Note:" in generated_soap:
        generated_soap_content = generated_soap.split("SOAP Note:")[-1].strip()
    else:
        generated_soap_content = "No SOAP note generated."

    # Print only the sample identifier and the raw SOAP note content
    print(f"Sample {i}\n{generated_soap_content}\n")

    # Store the generated and reference SOAP notes
    generated_soaps.append(generated_soap_content)
    reference_soaps.append(dataset[i]["soap"])

    # Clear memory
    del inputs, outputs
    torch.cuda.empty_cache()
# Out:
# Sample 0
# Subjective: The patient reports painless blurry vision in the right eye for one week, along with intermittent fever, headaches, body aches, and a non-pruritic maculopapular rash on both lower limbs present for six months. There is no associated neck stiffness, nausea, vomiting, Raynauds phenomenon, oral ulcers, chest pain, dyspnea, abdominal pain, or photosensitivity. Past medical history includes occasional episodes of left knee and testicle swelling but no known exposure to toxins or unhealthy lifestyle practices such as smoking, alcohol consumption, or illegal drugs. Currently employed as a flooring installer.
# Objective: Vital signs within normal limits. Physical examination revealed bilateral papilledema and optic nerve erythema more pronounced in the right eye compared to the left, accompanied by a right inferior nasal quadrant visual field deficit and a relative afferent pupillary defect. Muscle tone and deep tendon reflexes were unremarkable; sensory testing indicated intact responses to light touch, pin prick, vibratory stimuli, and proprioceptive input. Maculopapular rashes noted bilaterally over the lower limb areas. Laboratory studies demonstrated microcytic anemia with decreased hemoglobin levels 11.6 gmdl, hematocrit 35.3, MCV 76.9 fl, elevated ESR 33mmhr, CRP 13.3mgdl, and low serum sodium concentration 133mml.
# Assessment: Differential diagnosis considerations include autoimmune disorders, vasculitis, infection, malignancy, and neurologic conditions affecting the eyes. Further investigations required to establish definitive etiology.
# Plan: Additional laboratory analyses including complete blood count, comprehensive metabolic panel, rheumatologic serologies, urine analysis, cerebrospinal fluid evaluation, and imaging studies will be conducted to aid in determining the underlying pathology causing these presenting complaints. Consultation with relevant specialists e.g., ophthalmologist, rheumatology, etc. may be sought based on initial diagnostic impressions. Close monitoring of symptoms and ongoing communication regarding management strategies will continue until a final diagnosis is established.
#
# Sample 1
# Subjective: The patient is a 7-year-old male with congenital bilateral sensorineural deafness who previously underwent a failed right cochlear implantation. He reports no discomfort during recent magnetic resonance imaging mri procedures where his airway was maintained with a cuffed endotracheal tube ett.
# Objective: A size 5.5 mm internal diameter uncuffed ett was utilized for securing the patients airway during the mri scan. Intraoperative neurophysiological monitoring including brainstem auditory sensory evoked potentials, brainstem mapping of cranial nerve cn ix x xi xii and their motor nuclei, and corticobulbar tract motor-evoked potential mep will be performed during the upcoming surgical intervention.
# Assessment: The planned surgery involves inserting an auditory brainstem implant abi due to previous failure of a cochlear implant. Neurological monitoring techniques such as brainstem auditory sensory evoked potentials, brainstem mapping of cn ix x xi xii, and corticobulbar tract meps will aid in ensuring proper functioning of these vital structures during the operation.
# Plan: On the day of surgery, the anesthesia team will place leads for cn ix x xi xii prior to intubating the patient again using a specially-prepared uncuffed ett equipped with laryngeal electrodes. Tiva total intravenous anesthesia consisting of propofol and remifentanil will be administered to maintain unconsciousness and analgesia throughout the procedure. Post-operative care and close monitoring will focus on assessing the success of the abi implant and managing any complications related to the surgery.
#
# Sample 2
# Subjective: The patient reports having undergone an ultrasound in April 2017 revealing a single thyroid nodule in the left lobe. Post-operative evaluation shows no complications during the initial period.
# Objective: Ultrasound imaging confirmed a single thyroid nodule measuring 1cm in the left lobe. Biochemical testing indicated elevated calcitonin levels at 40ngml, peaking at 1420ngml upon stimulation. Histopathology identified medullary thyroid carcinoma MTC within the excised tissue, along with focal areas of c-cell hyperplasia. No evidence of metastasis was detected in the lymph nodes examined.
# Assessment: Medullary thyroid carcinoma MTC diagnosed based on histologic features and elevated calcitonin levels. Initial post-surgical assessment reveals favorable outcomes without significant complications. Further surveillance required due to residual c-cell hyperplasia and potential recurrence risk.
# Plan: Continued close monitoring through routine check-ups and additional screenings as needed. Follow up with endocrinologist to manage calcitonin levels and monitor for possible recurrences.
#
# Sample 3
# Subjective: patient reports experiencing a progressive headache, nausea, and vomiting over one week; additionally noted right-sided weakness, ptosis, and diplopia beginning around the same time period. Initially experienced acute consciousness disturbances which resolved post-hospitalization.
# Objective: initial presentation included a GCS score of E3VAM5 upon admission. subsequent diagnostic testing indicated an enhanced brain tumor with necrotic cystic changes localized within the left temporal lobe extending into surrounding structures including the left basal ganglia and periventricular regions resulting in significant perifocal edema and midline shifts. histopathology confirmed classical glioblastoma multiforme gbm characterized by pleomorphic cellular morphology, hyperchromasia, prominent astrocytes, vascular proliferations, and areas of necrosis. post-operative treatments include radiation therapy and chemotherapeutic agents such as temozolomide administered for approximately six months. recent follow-ups indicate progression of disease evidenced through additional mass formations on mri scans prompting two additional surgical resections revealing mixed pathologies suggestive of both primary central nervous system lymphomas pcsnl and high-grade gliomas hgg exhibiting positive markers for idh1, p53, mgmt negative, and cd56 expression among others.
# Assessment: current assessment indicates recurrent malignant neoplasm involving multiple CNS sites previously diagnosed as gbms now showing evidence of pcsnls and hgg. ongoing surveillance required due to aggressive nature of malignancy and potential for metastasis despite prior interventions.
# Plan: continued monitoring via regular clinic visits necessary to assess efficacy of existing therapies and identify emerging complications associated with advanced stage cancerous growths. multidisciplinary team approach recommended to optimize management strategies based on evolving pathological characteristics.
#
# Sample 4
# Subjective: patient reports severe abdominal pain as the primary symptom, which worsened over several weeks prior to admission. Pain is described as persistent and debilitating despite treatment interventions.
# Objective: initial diagnosis upon admission included severe acute pancreatitis. vital signs showed elevated blood pressure during periods of withdrawal symptoms. laboratory results not provided due to lack of documentation.
# Assessment: patient diagnosed with recurrent episodes of severe acute pancreatitis post-liver transplant. current management includes continued use of opioids to manage pain associated with pancreatitis.
# Plan: ongoing management involves adjusting dosages of analgesics based on subjective feedback regarding pain levels. additional treatments include administration of antibiotics, fluids, and pancreatic enzymes. future plans involve gradual reduction of opioid doses through alternative delivery methods such as patches to minimize risk of withdrawal symptoms. close monitoring required to assess effectiveness of treatment strategies and adjust accordingly.
#
# Sample 5
# Subjective: The patient presented with chronic progressive dyspnea and intermittent right-sided chest pain. He denied smoking habits and occupational exposure to asbestos.
# Objective: Physical examination showed reduced lung sounds on the right side without signs of autoimmunity. Chest x-rays indicated significant right lung volume loss accompanied by pleural effusion. Computed tomography confirmed these findings along with pleural thickening. Additional tests ruled out traumatic injury, tuberculosis, pneumothorax, pulmonary hypertension, diaphragmatic dysfunction, and malignancy. Positron emission tomography-computed tomography revealed high uptake in the affected area. Surgical lung biopsy did not reveal malignant or infective lesions.
# Assessment: The patient experienced severe restriction of breathing function despite treatment with cortisone. Autopsy concluded diffuse fibrous pleuritis without evidence of cancerous growths such as mesothelioma.
#
# Plan: Prednisolone therapy was prescribed initially; however, it failed to improve the patients condition leading to his death caused by a cardiac ischemia event.
#
# Sample 6
# Subjective: patient reports experiencing body weight loss; has a history of hypertension and diabetes, both controlled on medication. expresses concern upon learning about his colorectal cancer diagnosis.
# Objective: lab results show decreased hemoglobin levels at 9.1 gdl. tumor markers are within normal range. colonoscopy reveals a circumferential tumor in the sigmoid colon confirmed as an adenocarcinoma with rasmutation. ct imaging indicates irregular colonic wall thickening involving the urinary bladder with enlarged regional lymph nodes suggesting metastatic spread, though no distant metastasis detected. staging is lacc iiic t4bn2m0 based on pre-treatment evaluation.
# Assessment: diagnosed with locally advanced rectal adenocarcinoma with rass mutation, staged as lacc iiic t4bn2m0. pathology report confirms grade 1a response to neoadjuvant therapy ypt4byn0ymstage iic.
# Plan: initiated with loop transverse colostomy followed by six cycles of chemoradiation including capox and bevacizumab. subsequent surgery included sigmoidectomy and partial cystectomy. post-operative care managed successfully without complications such as neurogenic voiding dysfunction or urinary incontinence. continued with eight cycles of adjuvant chemotherapy using capecitabine. currently disease-free at sixteen-months post-diagnosis under close monitoring.
#
# Sample 7
# Subjective: The patient reports a 6-month history of swelling in the left floor of the mouth, accompanied by difficulty in swallowing. He experiences mild pain upon pressing the affected area but denies any associated pain, numbness, or weakness in his tongue.
# Objective: Intraoral examination reveals a well-defined, solid, spherical submucosal nodule measuring approximately 3.5 x 3 x 2 cm located near the sublingual gland, covered with light bluish mucosa. Palpable pressure elicits minimal discomfort at the site. Lab studies show no abnormalities, and imaging shows a 2.8 x 1.8 x 2.1 cm solid, heterogeneous mass involving the left floor of the mouth with increased vascularity; no involvement of the mandible was noted. Enlarged lymph nodes were not identified in the submandibular or submental regions.
# Assessment: Initial clinical impressions include a possible benign salivary gland tumor, dermoid cyst, or benign connective tissue neoplasm based on the location, size, and characteristics of the lesion.
# Plan: Surgery via an intraoral approach is planned to address the suspected pathology. Post-operative fixation and submission of the resected specimen for histopathology will aid in determining the definitive diagnosis and appropriate treatment course.
#
# Sample 8
# Subjective: patient reports tingling and numbness in right arm and leg for over a month; difficulty walking due to unsteadiness requiring assistance; no smoking, drinking, or drug usage history; diagnosed with prostate cancer treated by prostatectomy.
# Objective: vital signs upon admission include temperature 97.9F, heart rate 68 bpm, blood pressure 13784mm Hg, and respiratory rate 18 breathsmin. neurologic examination reveals right-sided hemiparesis and significant leg stiffness, with muscle strength rated as 45 in the right arm and 35 in the right leg. other cranial nerve functions appear intact except for limited range of motion in the neck and shoulders. lab results show normal ranges across all parameters tested.
# Assessment: diagnosis of chronic spinal stenosis based on radiographic evidence of moderate-to-severe central stenosis with cord compression at c34c56, accompanied by mild edema at those levels. additional degenerative changes noted throughout the cervical region, including vertebral body osteophytes and facet joint arthrosis.
# Plan: referral to orthopedic specialists for further evaluation and management planning specific to spinal stenosis. close monitoring required given existing risk factors such as prior malignancy and advanced age. regular follow-ups recommended to assess response to treatments and identify any complications early on.
#
# Sample 9
# Subjective: patient reports experiencing severe back pain starting approximately 4 days prior without apparent trigger; symptom progression resulted in worsening pain, nausea, and limited mobility; denies headaches concurrent with back pain but confirms ongoing severe back pain as primary concern; past medical history includes hypertension and lumbar spinal canal stenosis, not currently managed by oral anticoagulants or anti-platelets; orientational disturbances noted during physical assessment.
# Objective: vital signs recorded upon presentation include temperature 36.2c, blood pressure 192109mmhg, heart rate 79 bpm; glasgow coma scale gcs scored e4v4m6 indicating mild cognitive impairment; neurological examinations show no evidence of sensory deficits or motor weaknesses in lower extremities; routine lab work including hematological parameters and coagulation studies within reference ranges; radiographic evaluations reveal no significant vertebral anomalies; magnetic resonance imaging mri results indicate a bandlike signal hyperintense t1 hypointense t2-stir spanning th2-l3 levels suggestive of extradural compression, most prominent at th7 affecting surrounding spinal structures.
# Assessment: presenting complaints consistent with acute exacerbation of pre-existing lumbar spinal canal stenosis likely precipitated by underlying degenerative disc disease; differential diagnoses may include herniated nucleus pulposus hnp, spinal tumor, or infectious etiology such as epidural abscess; given lack of focal neurologic deficit, non-specific nature of subjective symptoms, and negative serologic testing, alternative explanations appear less probable at this time.
# Plan: initiate conservative management strategies focused on analgesic therapy and supportive care pending definitive diagnosis; consider referral to interventional spine specialists for possible minimally invasive procedures like percutaneous laser decompression pld if indicated based on evolving clinical picture; monitor for development of new focal neurologic deficits or systemic inflammatory markers indicative of infection; schedule repeat mris scheduled every two weeks to assess response to current interventions and track progress towards resolution.
#
# Sample 10
# Subjective: The patient reports a history of seizures and abnormal neurological findings due to HHH syndrome diagnosed at 4 years old. She also experiences developmental difficulties including expressive language and attention problems, confirmed by a neuropsychological assessment. Additionally, she suffers from severe myopia. Her past medical history includes two uncomplicated pregnancies resulting in healthy babies, one complicated pregnancy involving seizure onset at 22 weeks gestational age requiring initiation of antiepileptic therapy carbamazepine and subsequent cesarean delivery at term with no further seizures noted. Postnatal care included monitoring of moderate elevations in serum ornithine concentrations which normalized within 24 hours along with an elevation in blood ammonia levels managed through administration of sodium benzoate and intravenous arginine. Current dietary management consists of a protein-restricted diet initially set at 1.5 grams per kilogram daily bodyweight during childhood.
# Objective: Vital signs include blood pressure 12070 mmHg, pulse rate 80 beatsminute, temperature 36.8 degrees Celsius, and oxygen saturation 98 while breathing room air. Physical examination reveals height below the 3rd percentile and weight at the 25th percentile. Neurological examinations show abnormalities consistent with prior diagnoses of HHH syndrome. Brain imaging revealed multiple small calcifications without evidence of vascular malformations. Laboratory results indicate mildly elevated ornithine levels during the second pregnancy, subsequently decreasing to normal ranges, and elevated blood ammonia levels managed pharmacologically.
# Assessment: The patient presents with a complex medical history characterized by HHH syndrome, developmental delays, and visual impairment. Past obstetric histories demonstrate successful outcomes despite initial challenges related to maternal conditions. Continued close monitoring required for ongoing management of underlying disorders and associated comorbidities.
#
# Plan: Maintain current therapeutic interventions comprising protein-restriction diets, anticonvulsant therapies, and targeted pharmaceuticals for managing ornithine and ammonia imbalances. Schedule regular appointments with healthcare providers to assess progress and adjust treatments accordingly based on evolving needs. Encourage open communication regarding changes in symptomatology or new developments affecting overall health status. Provide educational resources to support self-management strategies and promote optimal quality of life.
#
# Sample 11
# Subjective: A 36-year-old female patient reports frequent headaches during her current pregnancy at nine weeks gestational age. She denies any associated visual disturbances, chest pain, shortness of breath, or other neurological symptoms. Her past obstetric history includes preeclampsia at 27 weeks followed by preterm delivery via cesarean section due to intrauterine growth restriction at 36 weeks. Family history reveals paternal ischemic heart disease and maternal hypertension.
# Objective: Laboratory results show mild elevation in erythrocyte sedimentation rate esr at 16 mmh but within reference range of up to 30 mmh. Other lab values such as creatinine, alanine transaminase alt, aspartate transaminase ast, alkaline phosphatase alp, total bilirubin tbil, albumin alb, blood urea nitrogen bun, urinalysis ua including protein levels, and complete blood count cbc were all unremarkable except for slightly increased crp at 3.8 mgdl. Imaging studies reveal 75 percent stenosis of the infrarenal aorta without evidence of thrombosis or dissection. Collateral vessels appear intact.
# Assessment: Differential diagnoses for the identified infra-renal aortic stenosis include congenital abdominal coarctation, takayasus arteritis, fibromuscular dysplasia fmd, aortic neurofibromatosis nf1, aortic tuberculosis, and radiation-induced aortitis. Given the lack of clinical features suggestive of nf1, tuberculosis, or radiation exposure, along with minimal inflammatory markers, the most likely possibilities are either congenital abdominal aortic coarctation, fmd, or an inactive phase of takaysu arteritis.
# Plan: Close monitoring of patients pregnancy and headache status will be conducted. Regular appointments scheduled to assess progress and address any emerging issues. Continued use of prescribed medications aspirin 100mg and calcium carbonate 1200mg per day recommended. Further diagnostic workup may be considered depending on symptom progression or new developments.
#
# Sample 12
# Subjective: patient reports experiencing difficulty walking starting 3 days prior, initially presenting as discomfort followed by pain without any known trauma or events triggering onset; no associated swelling noted; temporary improvement after receiving an intraarticular injection of xylocaine, subsequently developed intermittent catching sensations upon movement.
# Objective: physical examination reveals severe restriction of knee range of motion secondary to pain; all ligamentous stability testing including lachmanns test, pivot shift test, varus-valgus stress testing, and mcmurrays test unremarkable; plain x-rays show normal bony structures; magnetic resonance imaging demonstrates a soft-tissue mass adjacent to the knee joint exhibiting high signal intensity on t1 and t2 weighted sequences, low signal intensity on fat suppressed sequences, and non-enhancement post-gadolinium administration; laboratory studies within normal limits.
# Assessment: diagnosis of symptomatic knee effusion likely contributing to mechanical symptoms such as clicking and locking; presence of a soft tissue mass suggestive of benign etiology based on histopathological evaluation during surgical excision.
# Plan: recommendation made for knee arthroscopic intervention to address underlying cause of ongoing symptoms despite conservative management efforts; successful removal of a mobile adipose-based lesion via piecemeal debridement confirmed via pathology report ruling out malignancy or inflammatory conditions; close monitoring advised for potential recurrence or complications.
#
# Sample 13
# Subjective: The patient reports severe pain in the right upper quadrant of the abdomen, specifically localized to the right side. This pain is consistent with a diagnosis of chronic calculous cholecystitis with aberrant bile duct flow into the cystic duct.
# Objective: A computed tomography ct scan revealed a gallstone within the thickened gallbladder wall and increased ct values indicating inflammation around the organ. Magnetic resonance cholangiopancreatogram mrcp identified the presence of an aberrant right hepatic duct arhd draining into the cystic duct. Intraoperatively, the arhd was found to drain only a small portion of the liver before joining the main biliary system via the cystic duct. Removal and ligation of the arhd was completed using aesculap ds titanium lig clips.
# Assessment: The patient underwent a successful laparoscopic cholecystectomy with removal and ligation of the arhd. Post-operatively, the patient requires close monitoring and regular check-ups to ensure appropriate healing and prevent complications associated with the condition.
#
# Sample 14
# Subjective: patient is a 50-year-old african american female presenting with a three-week history of intractable headaches, confusion, vertical binocular diplopia, photophobia, and imbalance.
# Objective: vital signs within normal limits. ophthalmologic examinations show bcva at 2025 od and 2020 os, iop at 14 mmhg bilaterally, no afferent pupillary defects, full extraocular movements and confrontation visual field testing. anterior segments appear unremarkable. posterior segment exams reveal grade iv optic disc edema, blurred margins, obscured vascular structures, preretinal and intraretinal hemorrhages primarily around the papillomacular bundle but extending into the peripheral retina. oct confirms optic nerve swelling. fluorescein angiogram shows hyperfluorescent discs bilaterally. csf analysis reveals elevated wbc count with increased lymphocyte predominance, high protein levels, low glucose concentration, all within reference ranges except for the protein level which exceeds the upper limit of normal range. bacterial, fungal, lyme disease, hsv, west nile virus serologies, ana, p-anca, and respiratory viruses panels returned negative results.
# Assessment: differential diagnosis includes idiopathic inflammatory conditions such as sarcoidosis, neurosarcoidosis, multiple sclerosis, neuromyelitis optica spectrum disorder, infectious etiologies like toxoplasmic chorioretinitis, tuberculosis, cryptococcal meningitis, coccidioidal meningitis, tuberculous meningitis, and others including autoimmune disorders, neoplastic processes, and metabolic derangements. given the absence of typical features suggestive of these entities, further investigations are required to establish a definitive diagnosis.
# Plan: initiate workup for suspected central nervous system inflammation by ordering lumbar punctures, mri scans, and other relevant diagnostic procedures. monitor csf parameters over time to assess response to therapy if indicated. consult with specialists across disciplines to arrive at a consensus regarding management strategies based on evolving clinical picture.
#
# Sample 15
# Subjective: patient reports severe left back pain and left axillary numbness and paresthesia
# Objective: MRI shows tumor attachment to T2 and T3 vertebrae, infiltrating nerve roots; no direct tumor invasion of left brachial plexus or subclavian vessels confirmed via imaging
# Assessment: stage iib nsclc in the left upper lobe causing compression and infiltration of surrounding structures resulting in pain and sensory disturbances
# Plan: scheduled for posterior approach, image-guided t2 and t3 osteotomy followed by transthoracic en bloc resection under navigational guidance to address tumor-related complications
#
# Sample 16
# Subjective: A 70-year-old female patient presents with chief complaints of chest distress lasting 11 hours, accompanied by shortness of breath even at rest and difficulty lying down in the supine position. She reports a past diagnosis of hypertension and diabetes mellitus treated with oral medications.
# Objective: On admission, she exhibited no fever but experienced moderate discomfort when palpated over her abdomen, particularly in the left lower quadrant. Signs suggestive of peritoneal irritation were noted as well. Physical examination revealed a neoplastic-like mucus clot attached to the anal region. Laboratory studies indicated decreased hemoglobin level (102g/l), elevated prothrombin time (13.4s), and increased international normalized ratio INR of 1.2.
# Diagnostic procedures include a colonoscopy revealing a submucosal mass in the sigmoid colon with partial rupture of the mucosa and associated clots obstructing passage, confirmed via computed tomography ct scans showing a submucosal hematoma in the sigmoid colon and thickening of the left colonic flexure likely due to additional hemorrhage.
# Assessment: Based on these findings, the primary differential diagnoses considered are gastrointestinal bleeding secondary to recent cardiac surgery involving administration of heparin, specifically post-angioplasty syndrome PAS, and possible complications related to existing comorbidities such as hypertension and diabetes mellitus.
# Plan: Given the persistence of symptoms despite conservative management including cessation of anti-coagulants, total parental nutrition tpn, and close observation, alternative therapeutic strategies need to be explored. Further evaluation is required to determine appropriate interventions based on the underlying cause identified through ongoing investigations.
#
# Sample 17
# Subjective: The patient is a 64-year-old postmenopausal woman presenting without symptoms or palpable masses. She reports a past history of hysterectomy due to symptomatic fibroids and denies familial cancer histories. Her recent screening mammogram was normal, while previous imaging studies indicated multiple osteolytic lesions and enlarged lymph nodes suggestive of metastasis.
# Objective: Colonoscopic examination identified an adenocarcinoma, later determined by immunohistology to be consistent with a breast origin. Subsequent investigations including FNA, PET scan, and biopsies confirmed metastases to regional lymph nodes and bones. Laboratory testing revealed elevated tumor markers such as carcinoembryonic antigen cea at 2.08ngml, ca 19-9 at, and ca 125 at 6.4uul, all above their respective reference ranges.
# Assessment: The patient has been diagnosed with stage IV metastatic breast cancer, specifically infiltrating ductal carcinoma, with involvement of local lymphatics, distant organs, and bones. Histopathological analysis indicates estrogen receptor positivity er pr and gata-3 expression ck-7, confirming its breast origin.
# Plan: The patient initiated therapy with anastrozole, awaiting further diagnostic procedures. Future management plans will involve close monitoring under the guidance of her oncologist, considering additional treatments based on disease progression. Patients should continue routine check-ups and promptly report any changes in health status.
#
# Sample 18
# patient complains of pain and swelling in the right submandibular region present for approximately ten days duration. exacerbates intermittently during meals resolving afterward; unpleasant sensation experienced upon consumption of sour or acidic foods.
# physical examination reveals localized swelling over the right submandibular area without evidence of purulent drainage. intraoral inspection shows an enlarged mass at the base of the tongue bilaterally, more prominent on the right side. bimanual palpation identifies a firm immobile lesion within the affected submandibular gland.
# diagnosis suspected as right-sided submandibular sialolithiasis based on subjective reports and physical examinations. imaging studies such as ct scans required for confirmation.
# surgical intervention planned involving risdon incisions extending inferiorly from the anterior border of the ascending ramus of the mandible down to the level of the hyoid bone. identification and protection of the marginal branch of facial nerve followed by dissection of the sublingual space separating the submandibular gland from its attachment to the mylohyoid muscle. division and ligation of the submandibular duct leading to excision of the entire gland including embedded calculus measuring up to seven millimeters in diameter.
# post-operative care includes placement of suction drains and closure in multiple tissue planes to mitigate potential risks like infection or hematoma formation. regular follow-ups scheduled to assess progress and detect possible adverse effects.
#
# Sample 19
# Subjective: The patient reports difficulty with attention, hyperactivity, and repetitive behaviors. He struggles specifically with mathematical concepts and verbal skills such as comprehension and fluency. These issues began manifesting during childhood but no other significant health complaints exist.
# Objective: At age eight, the patients WISC-III score was below average in both VIQ and PIQ categories, while his performance IQ fell within normal range. His overall intelligence quotient is slightly below average according to the test norms.
# Assessment: Based on the objective assessment, the patient exhibits signs consistent with Attention Deficit Hyperactive Disorder ADHD and specific learning disabilities related to mathematics and language processing. Further testing may reveal comorbidities or coexisting conditions.
# Plan: Given the diagnosis, treatment options include cognitive behavioral therapy CBT to manage ADHD symptoms and specialized tutoring sessions tailored towards addressing the learning disability. Additionally, regular monitoring by healthcare professionals will allow for adjustments based on progress made over time.
#
# Sample 20
# Subjective: The patient reports worsening dyspnea, increased difficulty breathing, persistent cough, and decreased oxygen saturation over the past few months. He expresses concern regarding his current state and fears exacerbation of pre-existing conditions.
# Objective: Medical history includes lcSSc, PAH, and ILD. Past treatments include albuterol inhalers as needed, discontinuation of mycophenolate mofetil six years prior due to perceived risks associated with chronic lyme disease, and previously effective combination therapies including tadalafil and macitentan. Recent RHC shows worsening PAH with elevated mean PA pressures at 72mmHg and reduced cardiac index at 1.7Lminm2 despite initiation of subcutaneous treprostinil three months ago.
# Assessment: The patients presenting complaints suggest progression of underlying PAH and possible complications related to ILD. Discontinuing mycophenolate mofetil may be contributing to the rapid decline in health status. Continued monitoring is necessary to assess response to newly initiated treprostinil and determine potential adjustments to existing therapeutic regimens.
# Plan: Refine treatment strategy based on objective measurements such as serial RHCs and pulmonary function testing. Consider alternative immunosuppressive agents for management of ILD given previous intolerance to mycophenolate mofetil. Schedule frequent follow-up visits to evaluate effectiveness of interventions and address emerging issues promptly. Provide education on self-management strategies to optimize outcomes and minimize adverse events.
#
# Sample 21
# Subjective: The patient reports experiencing fever, muscle pain, and vomiting for the past four days along with excessive thirst, frequent urination, nocturia, and unintentional weight loss persisting for approximately one month. There is no significant personal or family history of diabetes mellitus or smoking habits, nor consumption of alcohol or illegal substances. The patient denies using tobacco products, alcohol, or illicit drugs.
# Objective: On presentation, the patients vital signs include blood pressure of 11580 mmHg, body temperature of 366C, and heart rate of 964 bpm. Physical examination reveals dehydration but no other notable features. Laboratory investigations show elevated venous plasma glucose level at 467mgdl, indicative of hyperglycemia. Metabolic acidosis and increased serum beta-hydroxybutyrate concentrations indicate diabetic ketoacidosis DKA. Electrocardiography shows sinus tachycardia, while chest radiograph exhibits normal findings. Blood test results confirm dengue virus infection, characterized by hemoconcentration, thrombocytopenia, and hemorrhage-related manifestations consistent with dengue hemorrhagic fever DHF.
# Assessment: Diagnosed with diabetic ketoacidosis secondary to type-2 diabetes mellitus complicated by concurrent dengue hemorrhagic fever. Differential diagnosis includes leptospirosis due to similar presenting complaints such as fever, myalgias, headache, nausea, diarrhea, and rash. However, serological testing ruled out leptospira antibodies.
# Plan: Immediate management involves administering 1-liter isotonic saline within one-hour followed by maintenance fluids at 500mlhr. Potassium replacement therapy initiated alongside continuous insulin infusion. Chest discomfort noted post-treatment prompting reduction of IV fluid intake from 140 mlhr to 6080 mlhr monitored hourly for positive fluid balance. Further evaluation required to determine appropriate antiviral regimen for managing co-morbidities.
#
# Sample 22
# Subjective: patient reports persistent hoarseness and difficulty swallowing since three months ago after experiencing an upper respiratory infection; no additional symptoms noted except those mentioned above
# Objective: physical examination reveals paralysis of the right vocal cord; ct scan shows an enlarged thyroid gland with multiple bilateral thyroid nodules; previous FNAs indicated atypia of undetermined significance and benign follicular nodule; surgery confirmed moderate enlargement of the right thyroid lobe with multiple nodules without extrathyroidal extension
# Assessment: patient presents with hoarseness and dysphagia due to compression caused by an enlarged thyroid gland containing multiple nodules; pathology indicates nodular thyroid hyperplasia and metastasis of previously treated invasive ductal carcinoma of the breast
# Plan: ongoing surveillance required given presence of metastases; close monitoring necessary to assess response to current treatments and potential changes needed
#
# Sample 23
# Subjective: patient reports initial presentation with a strangulated large bowel and ventral hernia, 10 years post-laparoscopic adjustable gastric banding lagnb procedure; experienced a port-site infection one year ago followed by surgery involving suturing of tubing to abdominal wall; currently experiencing abdominal sepsis due to complications six months after reversal of ileostomy.
# Objective: previous ct scan showed stable positioning of lagb tubing near transverse colon without concern for penetration; recent ct revealed transection of remaining proximal transverse colon by lagb tubing necessitating right hemicolectomy and creation of end ileostomy.
# Assessment: patient exhibits signs of acute abdomen secondary to complications arising from prior surgeries related to lapband device placement. existing conditions include morbid obesity and previously diagnosed port-site infection.
# Plan: ongoing monitoring required to assess healing process and identify potential complications associated with the lagb device. future interventions will be tailored based on patient response and further evaluation results.
#
# Sample 24
# Subjective: patient reports gradual worsening of metamorphopsia and decreased visual acuity in both eyes over the past four months; no previous complaints of color or peripheral vision changes, nor hearing impairment; diagnosed with beta thalassemia intermedia managed with regular blood transfusion and chelation therapy using deferoxamine infusions and oral deferiprone, along with thyroid replacement medication.
# Objective: BCVA measured at 2025 OD and 2017 OS; slit-lamp examination unremarkable; intraocular pressures 14mm Hg bilaterally; dilated funduscopic evaluation shows bilateral yellowish macular lesions surrounded by RPE changes and angioid streaks radiating from the optic nerve head without affecting the macula; OCT reveals a subfoveal hyper-reflective deposit consistent with the macular lesion; FA demonstrates staining of the macular lesion in later frames; FAF displays mild stippling in the macular region.
# Assessment: differential diagnosis includes age-related macular degeneration AMD, central serous choroidal detachment CSCD, and drug-induced toxicity due to long-term use of iron-chelators such as deferoxamine. given patients history of beta-thalassemia requiring chronic iron-chelator therapy, further workup including ERG required to investigate possibility of dfo-retinopathy.
# Plan: scheduled electrophysiologic assessment including full field electroretinograms FFER to confirm presence of dfo-retinopathy. post-test discussion and management strategy based on test outcomes will be determined. patient advised to schedule follow up consultation once test completed.
#
# Sample 25
# Subjective: patient reports experiencing typical chest pain for one week, worsening three hours prior to presentation, accompanied by dyspnea, nausea, and profuse sweating.
# Objective: vital signs include blood pressure 11070 mm Hg, pulse 54 bpm, respiration 22 breaths per minute, and body temperature 37 C. neurologic examination shows no abnormality. electrocardiogram reveals sinus rhythm at 54 bpm, left ventricular hypertrophy, horizontal st segment depression, t-wave inversion in leads iavl v46, and biphasic t waves in leads v23. lab values indicate elevated triglycerides at 273 mgdl but normal LDL, HDL, CBC, renal function, liver enzymes, CK-MB, hs-troponin, and INR 1.28.
# Assessment: diagnosis includes acute myocardial infraction mi due to non-ST elevation myocardial infarction nstemi based on electrocardiographic changes and elevated cardiac biomarkers ck-mb and hs-troponin. additionally, there may be underlying issues related to poor compliance with anticoagulant therapy warfarin, leading to subtherapeutic INR value.
# Plan: immediate management involves administering antiplatelet agents such as aspirin and clopidogrel, alongside parenteral anticoagulation using fondaparinux to manage acute MI complications. ongoing monitoring will assess response to treatment and identify potential risk factors like noncompliance with warfarin regime. future interventions may involve optimizing lipid profile through lifestyle modifications and medication adjustments, addressing comorbidities like hypertension and hypercholesterolemia, and considering revascularization procedures depending on angiographic findings.
#
# Sample 26
# Subjective: patient reports difficulty tolerating solid food; symptoms significantly improved after conservative management including antireflux medication and full liquid diet. recently experienced lightheadedness and shortness of breath leading to rehospitalization.
# Objective: initial workup revealed normal positioning of gastric band but presence of esophagitis and gastritis resulting in swollen mucosal tissue near the band site. subsequent removal of fluid from the reservoir and treatment led to improvement. recent laboratory results show elevated white blood cell count 18,000 cellsul1, indicating possible infection. imaging studies indicate mild inflammation around surgical sites without evidence of leakage until later stages.
# Assessment: patient underwent successful conversion from laparoscopic adjustable gastric banding to laparoscopic vertical sleeve gastrectomy with minimal complications. current presentation suggests potential complication related to surgical intervention, specifically pulmonary embolism confirmed by ct angiogram. further investigation required to assess impact on previous procedure.
# Plan: immediate transfer to specialized facility for definitive care of pulmonary embolism. ongoing monitoring necessary to evaluate effectiveness of existing treatments and identify any signs of complications such as leaks or infections. close collaboration between healthcare providers involved in patients case essential to ensure optimal outcomes.
#
# Sample 27
# Patient demographics: Newborn female infant born at 40 weeks by normal vaginal delivery; mother aged 29 years without complications throughout pregnancy.
# Chief complaint: No specific chief complaints noted at current visit.
# History of present illness: Uncomplicated postnatal period with no significant symptoms since birth.
# Past surgical history: None.
# Medical history: Mother reports a history of severe eczema in her 17-month-old son and two distant paternal relatives with alopecia, one starting in adolescence.
# Social history: Non-smoking parent, alcohol use unknown. Both parents are of European descent with no known consanguineous relationships.
# Physical examination: All vital signs within normal limits. Proportionate body habitus, no abnormalities detected upon gross inspection.
# Laboratory data: Normal lab values including complete blood count cbc, comprehensive metabolic panel cmp, urinalysis ua, thyroid-stimulating hormone tsh, and liver function tests lfts.
# Genetic testing: Whole exome sequencing performed, no clinically relevant variants identified.
# Diagnosis: Healthy newborn female infant, currently asymptomatic with no concerning past medical history or family history. Genetic screening negative for high-risk mutations.
# Plan: Continue routine well-child visits per American Academy of Pediatrics guidelines. Monitor patient closely for development of skin-related conditions such as eczema or alopecia.
#
# Sample 28
# Subjective: A 48-year-old female patient reports noticing a palpable mass in her left ring fingers distal phalanx, which she previously had diagnosed as enchondroma at another institution.
# Objective: Ultrasound examination showed an exophytic hypoechoic mass attached to the medullary cavity via disrupted cortical bone without evidence of vascularization or calcifications. Traditional ultrasound characterization was inconclusive due to limited capabilities.
# Assessment: Given the previous diagnosis of enchondroma, the current lesion may represent either recurrence or progression of the disease. Further imaging modalities, including magnetic resonance imaging mri or biopsy, will be necessary to differentiate between these possibilities and guide management decisions.
# Plan: Schedule an mri or biopsy within one week to obtain additional information regarding the nature of the mass and its relationship to the surrounding tissue. Monitor for any changes in size, shape, or consistency of the mass during this time period. If significant alterations occur or if the patient experiences increased discomfort or pain, immediate evaluation should be sought.
#
# Sample 29
# Subjective: patient reports recurring amnesic episodes lasting a few minutes upon waking, accompanied by disorientation and repetitive questioning; similar episodes occurring throughout the day involving brief trances, occasionally associated with repetitive swallowing movements and self-questioning; awareness of some episodes without complete recall; loss of new memories over time, difficulty remembering autobiographical events from adult life and familiar routes; persistent olfactory hallucination smelling like candy floss, present daily independent of amnestic episodes; subjective reduction in sense of smell; frequent migraine-type headaches; bilateral postural limb tremors; paresthesia in lower extremities; fatigue; and depressive symptoms previously treated. History includes previous heavy alcohol consumption.
# Objective: initial brain mri demonstrated subtle t2 hyperintensity in the right hippocampal region; electroencephalogram eeg within normal limits; physical examination negative for focal neurologic deficits. laboratory studies pending.
# Assessment: tentative diagnosis of transient epileptic amnesia tea initially managed with lamotrigine titrated from 25mg to 100mg bid resolving amnestic episodes while leaving other symptoms unchanged.
# Plan: ongoing management focused on addressing remaining symptoms including headaches, sensory disturbances, and olfactory hallucinations. close monitoring of response to current medication regimen and potential adjustments based on symptom progression. additional diagnostic testing underway to determine underlying cause of symptoms and appropriate interventions.
#
# Sample 30
# Subjective: patient reports constant blurry vision in the left eye for approximately six weeks; no smoking or drug usage; history includes cystic fibrosis leading to insulin dependent diabetes mellitus, chronic sinusitis, hypertension, iron deficient anemia, and obstructive sleep apnea; underwent sinus surgery seven months ago involving bilateral maxillary antrostomies, ethmoidectomies, sphenoidectomies, and frontal sinusotomies; current medication regimen consists of albuterol, azithromycin, itraconazole, insulin, lisinopril, pancreatic enzymes, and sulfamethoxazole trimethoprim.
# Objective: upon examination, visual acuity is 2040 bilaterally, intraocular pressures measured as 18mmHg od and 16mmHg os, pupillary reaction is 46mmspherical and reactive bilaterally; anterior segment exam shows no abnormalities; posterior segment exam reveals intraretinal hemorrhage along the nerve fiber layer with associated retinal thickening in the inferior macular region suggestive of branch retinal vein occlusion brvo in the left eye; OCT demonstrates mild intraretinal and trace subfoveal fluid in the left eye; FA confirms delayed venous filling in the inferior venous arcades of the left retina; vital signs include bp ranging from 110-145systolic and 7058diastolic within the last year, latest hba1c recorded 69 obtained 4months before presentation; CBC, vitamin A and D levels, PT, TT, AT, PCPS activities, cardiolipids, DRVVT, HCY, PTA20210a gene mutations are all within reference ranges except ANA mildly positive at 2.
# ...
#
# Sample 241
# Subjective: patient reports no pain or discomfort; unaware of significant physical abnormalities until informed by doctor; denies having any medical problems.
# Objective: delayed verbal responses noted during history-taking; facial asymmetry on left side, flattened nasal bridge, increased intercanthal distance 35 cm, frontal bossing 54 cm; multiple skin lesions on arms, right foot, and palmar/plantar pits present; painful hard swelling in left mandible; mild pain on percussion in all left mandibular posterior teeth; horizontal impactation of maxillary right second molar tooth; congenital absence of second premolars and third molars; bilateral radiolucencies associated with partially erupted mandibular second molar teeth, extending into mandibular ramus on left side; large lesion associated with impacted right maxillary second molar, extending into right maxillary sinus; severe expansion of lower left lesion in all dimensions, with perforations at buccal and lingual borders of mandible; calcifications detected in falx cerebri via skull x-rays.
# Assessment: multiple dental anomalies including caries, impactions, and congenital absences; enlarged bony lesions requiring further investigation and intervention prior to initiating orthodontic therapy; potential complications related to bone erosion and possible involvement of adjacent structures warrant close monitoring and multidisciplinary collaboration.
# Plan: initiate dental restoration procedures addressing carious teeth and affected areas; schedule consultations with relevant specialties e.g., oral surgeons, oncologists, etc.; coordinate efforts between dentistry and orthodontics teams to optimize overall treatment outcomes; recommend maintaining excellent oral hygiene practices and attending regular dental appointments; monitor progress of existing conditions and adjust treatment plans accordingly.
#
# Sample 242
# Subjective: patient reports no significant symptoms; referred due to a mixed ground-glass opacity lesion in the right upper lung discovered during screening.
# Objective: physical examination unremarkable; chest ct reveals a 34x20mm partially solid nodule with spiculation and pleural indentation at s3 (consolidation ratio 30%); petct shows suv=1.9 without evidence of distant metastases; kommerell diverticulum present at the origin of the left subclavian artery and a right-sided aortic arch identified via 3d ct reconstructions; echocardiogram negative for cardiac anomalies; right upper lobectomy completed using a three-port vats technique with no rib spreading.
# Assessment: diagnosis of invasive carcinoma confirmed by histology; no anatomical variants noted among pulmonary vessels or bronchi; subsequent radical mediastinal lymph node dissection undertaken successfully despite challenges exposing the left main bronchus.
# Plan: close monitoring and follow-ups scheduled to assess recovery progress and detect potential complications; post-operative care guidelines provided including specific instructions on managing symptoms and maintaining overall wellness.
#
# Sample 243
# Patient: A male child who suffered fatal injuries due to a high-speed car crash involving a frontal impact exceeding 79 mph while seated as a passenger without being involved in driving.
# History: Unknown prior medical conditions; no relevant family history provided by caregivers.
# Physical Examination: At presentation, patient was unresponsive and non-breathing. Attempts made to perform endotracheal intubation failed on-site.
# Diagnostic Tests: Radiographic imaging revealed internal decapitation with AO assimilation between the anterior arch of the atlas and the basiocciput, no other bone fractures detected.
# Treatment & Management: Immediate resuscitative efforts initiated upon admission to the ER, however, the patient succumbed shortly thereafter.
# Prognosis: Fatal outcomes confirmed based on vital signs deterioration despite intensive care measures.
# Follow-Up Care: Family counseled regarding the circumstances surrounding the tragedy and offered bereavement resources.
#
# Sample 244
# Subjective: patient reports progressive walking difficulties and stiffness in lower limbs since age 54, worse on the left side; no significant past medical or family histories provided.
# Objective: neurological examination revealed proximal upper limb weakness MRC 4-35 bilaterally, greater on the left, and left lower limb weakness MRC 45 bilaterally, again greater on the left; muscle tone preserved, hypotrophy of upper limb girdles, upper limb proximal muscles, and left lower limb; spontaneous fasciculation in proximal upper limb segments; negative sensory evaluation, cerebellar assessment, and babinski sign; positive exhaustible bilateral ankle clonus; reflexes intact except knee jerk and ankle jerk hyperreflexia; lab results within normal limits including blood cells, glucose, vitamins B12folate, inflammation markers, immunology, hepatitis serologies HIVHBCV, thyroidparathyroid function all normal; brain and spine MRI, CSF analysis unremarkable; EMG shows mild chronic neurogenic changes in selected muscles, active denervation in others; electroneurography indicates reduced cMAP amplitudes in one peripheral nerve.
# Assessment: possible diagnosis includes amyotrophic lateral sclerosis als, multiple system atrophy msa, hereditary spastic paraplegia hsp, and other forms of neuropathies. differential diagnoses include cervical spondylotic myelopathy csmy due to radiographic exclusion criteria.
# Plan: given the mixed presentation, additional testing is required to differentiate between these possibilities. we recommend conducting genetic studies, magnetic resonance spectroscopy mrs, and possibly lumbar puncture lp to aid in diagnosis. once confirmed, appropriate management strategies such as physical therapy, medication, and lifestyle modifications will be implemented based on specific disease type.
#
# Sample 245
# Subjective: The patient reports experiencing ataxia, tremors, and seizures, with concern over her developmental delays. She mentions having undergone various tests including an electroencephalogram eeg and discusses receiving treatment recommendations based on those results. Additionally, she reveals being diagnosed with hyperammonemia and informed of elevated ornithine and homocitrulline levels. Recently discovered pregnancy at approximately eight weeks.
# Objective: Test results indicate significantly elevated blood ammonia levels greater than 300 ugdl, beyond the normal threshold less than 80. Ornithine levels measured between 71186 umdla and homocitrulline levels within 510-643 m per 24-hour period exceed established norms. Maternal ammonia levels fluctuated between 74515 during labor and delivery.
# Assessment: Diagnosed with hyperammonemia, characterized by abnormally increased serum ammonia concentrations due to impaired metabolism or excretion. Elevated ornithine and homocitrulline levels suggest related metabolic imbalances. Pregnancy status necessitates adjustment of nutritional requirements to support fetal growth while managing mothers condition.
# Plan: Prescribed a specialized diet comprising lactulose, arginine, and reduced protein consumption to address hyperammonemia. Dietary adjustments implemented upon learning of pregnancy include incrementing daily protein intake up to 1.23 kgkgd to promote adequate nutrient supply for mother and fetus. Post-delivery monitoring includes continued management of maternal ammonia levels through periodic assessments and adherence to modified dietary regimen. Follow-up appointments scheduled to track patients and childs health outcomes.
#
# Sample 246
# Subjective: patient reports experiencing worsening abdominal pain persisting over two weeks, accompanied by bloody stools. denies recent episodes of nausea, vomiting, fever, or significant weight loss. no prior medical or surgical histories noted; no known familial history of malignancy.
# Objective: vital signs upon presentation indicated stability. physical examination revealed a painless palpable mass in the periumbilical area, left hypochondrium, and left flank. laboratory results show decreased hemoglobin levels initially at 133 gdl and later dropping to 86 gdl due to acute hemorrhage. diagnostic imaging via angio-computed tomography ct demonstrated a large exophytic mass measuring approx. 2031413cm originating from the fourth duodenum and proximal small intestine, exhibiting intra-tumor bleeding but without free intraperitoneal hemorrhaging. subsequent endoscopic evaluation failed to identify causative lesion within the lower gastrointestinal tract. emergency laparotomy confirmed presence of a large neoplastic growth involving the distal duodenum and proximal ileum, necessitating partial bowel resection and reconstruction through hand-sewn side-to-side anastomoses.
# Assessment: diagnosis includes large intestinal adenocarcinoma extending into the duodenum, causing severe acute hemorrhagic obstruction requiring emergent intervention. differential diagnoses include other primary tumors such as lymphomas, sarcomas, carcinoid tumors, etc.; however, given the histopathological features, adenocarcinoma appears most likely.
# Plan: immediate management included aggressive fluid resuscitation and multiple packed red cell transfusions to stabilize hemodynamics. urgent exploratory laparotomy was conducted revealing extensive involvement of the duodenoileal junction by a large ulcerating mass. affected segments were excised en bloc along with surrounding margins, followed by creation of a side-to-side anastomosis using interrupted silk sutures. post-surgical care will involve close monitoring of wound healing and overall progress towards recovery. further treatment modalities under consideration include adjuvant chemotherapy regimens tailored according to stage and grade of cancer, as determined by pathological analysis of resected specimen.
#
# Sample 247
# Subjective: patient reports persistent nausea and vomiting over the past four days; previously diagnosed with right-sided, multicentric, infiltrating lobular carcinoma of the breast ten years ago, stage 1a, ER+, PR+, HER2-, managed by right mastectomy followed by adjuvant therapy including anastrozole and regular surveillance imaging; experienced similar symptoms last year resulting in diagnostic procedures revealing gastric stenosis due to benign causes but currently presenting with recurrent symptoms despite previous interventions.
# Objective: recent CT scan of the abdomen and pelvis demonstrated mass-like thickening of the gastric antrum and distention of the proximal stomach; subsequent EGD confirmed esophagitis and gastric stenosis, resolved post-dilation via CRE balloon without fluoroscopic assistance; biopsy indicated mild chronic gastritis without helicobacter pylori involvement; repeat EUS identified gastric stenoses at the pyloric region and duodenum, successfully dilated with another CRE balloon reaching 13.5mm diameter; diffuse wall thickening of the gastric antrum measured up to 11mm, involving all layers as seen on EUS; histopathology results indicate invasive poorly differentiated metastatic breast cancer.
# Assessment: patient exhibits signs of recurrent gastrointestinal obstruction secondary to malignant progression of known primary malignancy, specifically metastasis of previously resected infiltrating lobular carcinoma of the breast.
# Plan: immediate referral to oncologist for further evaluation and management planning considering disease relapse and possible therapeutic options such as chemotherapy, targeted therapies, or palliative care depending on individual circumstances. close monitoring required given rapidity of tumor spread and potential complications associated with advanced stages of malignancies like these.
#
# Sample 248
# Subjective: The patient reports worsening swallowing function over the last nine months, leading to significant weight loss. He initially had improvement in neck pain post-surgery but has seen deterioration recently. History includes infectious cervical tuberculosis treated with antitubercular medication, hypertension, and mild diabetes mellitus. Current use of a nasogastric tube for nutritional support.
# Objective: Physical examination reveals left-sided proximal upper extremity muscle weakness with atrophy, dysesthesias in distal digits, and increased deep tendon reflexes bilaterally with upgoing toes. Oral examination shows left tongue atrophy and deviated toward the affected side. Laboratory results show mildly elevated CRP levels, within reference range otherwise. Imaging studies indicate erosion at the dens and anterior arch of the atlas, with a decrease in size of a retropharyngeal mass noted across time.
# Assessment: The patient presents with persistent infectious cervical tuberculosis affecting C1 vertebra, exhibiting signs of chronic inflammation and infection. Complications include progressive spinal deformity causing neurologic deficits, specifically involving the cranial nerve innervating the soft palate muscles resulting in impaired swallowing. Additionally, there is evidence of associated musculoskeletal changes such as muscular atrophy and sensory disturbances.
# Plan: Continued management involves close monitoring of disease activity through laboratory testing and radiological surveillance. Antitubercular therapy should be maintained per physician recommendations. Given the severity of dysphagia, ongoing use of a nasogastric tube for enteral supplementation remains necessary. Further evaluation by specialists may be considered for potential surgical intervention options aimed at addressing the underlying cause of neurologic compromise while managing infectious etiology.
#
# Sample 249
# Subjective: The patient reports multiple episodes of epistaxis over the past few days and impaired nasal breathing for several months due to nasal obstruction. He has a diagnosis of Crouzon syndrome but denies any significant family history related to his condition. His overall health status appears good as he doesnt report any additional complaints.
# Objective: Clinical examination reveals a polypoidal lesion projecting from the patients right nostril, facial asymmetry, and prominence of the ipsilateral canine fossa. Computed tomography imaging demonstrates a large, heterogeneous soft-tissue mass occupying the entire right nasal cavity, maxillary sinus, and ethmoidal cells, causing severe bony remodeling including loss of the anterior maxillary sinus wall, erosion of the posterior wall, and extension into the pterygopalatine fossa and orbital cavity. Laboratory studies indicate normal ranges across all parameters tested.
# Assessment: Based on the clinical presentation and radiographic findings, the primary diagnosis is sinonasal polyposis affecting the right side, likely contributing to the patients epistaxis and nasal obstruction. Differential diagnoses include neoplastic processes such as malignancy, though these appear less likely given the lack of invasive features noted during surgical exploration.
# Plan: Surgical intervention involved open excision through lateral rhinotomy and medial maxillotomy. Intraoperatively, the affected maxillary sinus mucosa was found to be entirely replaced by inflamed tissue, which could be separated cleanly from adjacent structures. Histology confirmed non-specific inflammation consistent with sinonasal polyposis, ruling out infectious etiologies like fungal infections. Post-operative management includes antibiotics, steroids, topical mometasone furoate spray, and intense nasal irrigation using saline solutions. Close monitoring will assess response to therapy and identify potential complications.

# %% [markdown]
# # Step 10: Evaluation

# %%
# Install dependencies for ROUGE, BERTScore, and BLEURT
# !pip install rouge-score bert-score
# Out:
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.11/dist-packages (0.1.2)
# Requirement already satisfied: bert-score in /usr/local/lib/python3.11/dist-packages (0.3.13)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge-score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from bert-score) (2.6.0+cu124)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from bert-score) (4.49.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from bert-score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.11/dist-packages (from bert-score) (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from bert-score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from bert-score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->bert-score) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->bert-score) (2025.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (0.29.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (0.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (3.2.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->bert-score) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->bert-score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->bert-score) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->bert-score) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.2)

# %%
# Initialize lists to store scores
rouge1_scores = []
rouge2_scores = []
rougel_scores = []
bertscore_f1_scores = []

# Initialize ROUGE scorer
rouge_scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# Compute metrics for each sample
for i in range(len(generated_soaps)):
    gen_soap = generated_soaps[i]
    ref_soap = reference_soaps[i]

    # Handle empty or invalid SOAP notes
    if not gen_soap or gen_soap == "No SOAP note generated." or not ref_soap:
        print(f"Skipping Sample {i}: Invalid or empty SOAP note.")
        rouge1_scores.append(0.0)
        rouge2_scores.append(0.0)
        rougel_scores.append(0.0)
        bertscore_f1_scores.append(0.0)
        continue

    # ROUGE Scores
    rouge_scores = rouge_scorer.score(ref_soap, gen_soap)
    rouge1_scores.append(rouge_scores['rouge1'].fmeasure)
    rouge2_scores.append(rouge_scores['rouge2'].fmeasure)
    rougel_scores.append(rouge_scores['rougeL'].fmeasure)

    # BERTScore with a different model to avoid warnings
    P, R, F1 = bert_score([gen_soap], [ref_soap], lang="en", model_type="bert-base-uncased", verbose=False)
    bertscore_f1_scores.append(F1.item())

# Compute averages
avg_rouge1 = np.mean(rouge1_scores)
avg_rouge2 = np.mean(rouge2_scores)
avg_rougel = np.mean(rougel_scores)
avg_bertscore_f1 = np.mean(bertscore_f1_scores)

# Print results
print("Automated Metrics Across All Samples:")
print(f"Average ROUGE-1 F1: {avg_rouge1:.4f}")
print(f"Average ROUGE-2 F1: {avg_rouge2:.4f}")
print(f"Average ROUGE-L F1: {avg_rougel:.4f}")
print(f"Average BERTScore F1: {avg_bertscore_f1:.4f}")
# Out:
# Automated Metrics Across All Samples:
# Average ROUGE-1 F1: 0.4703
# Average ROUGE-2 F1: 0.1897
# Average ROUGE-L F1: 0.3008
# Average BERTScore F1: 0.6934

# %% [markdown]
# # SOAP 2 Summarized and Explainable Report

# %%
# Clear memory after training
torch.cuda.empty_cache()

# %%
# Load the Hugging Face model
model_name = "Remiscus/MediGen"  # Replace with your preferred model if needed
generator = pipeline("text2text-generation", model=model_name)

# Function to create a prompt for summarization
def create_prompt(soap_note):
    return f"""
You are a medical assistant. Your task is to take a SOAP (Subjective, Objective, Assessment, Plan) report and generate a summarized, easy-to-understand explanation. The output should be clear and accessible to anyone without a medical background, avoiding jargon unless fully explained.

SOAP Report:
{soap_note}

Summarized and Explainable Report:
"""

# Function to generate the summary
def generate_summary(prompt):
    response = generator(prompt, max_length=500, num_return_sequences=1, temperature=0.01)
    return response[0]['generated_text']

# Read the CSV file
csv_file_path = '/content/output.csv'  # Replace with your actual CSV file path
df = pd.read_csv(csv_file_path)
df = df.head(5)
# Ensure the column name matches your CSV
if 'SOAP' not in df.columns:
    raise ValueError("The CSV file must contain a 'SOAP' column")

# Process each row
for index, row in df.iterrows():
    soap_note = row['SOAP']
    prompt = create_prompt(soap_note)
    simplified = generate_summary(prompt)

    print(f"\nRow {index + 1} - Original SOAP Note:\n", soap_note)
    print(f"\nRow {index + 1} - Summarized and Explainable Report:\n", simplified)
    print("=" * 100)
# Out:
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# The model 'LlamaForCausalLM' is not supported for text2text-generation. Supported models are ['BartForConditionalGeneration', 'BigBirdPegasusForConditionalGeneration', 'BlenderbotForConditionalGeneration', 'BlenderbotSmallForConditionalGeneration', 'EncoderDecoderModel', 'FSMTForConditionalGeneration', 'GPTSanJapaneseForConditionalGeneration', 'LEDForConditionalGeneration', 'LongT5ForConditionalGeneration', 'M2M100ForConditionalGeneration', 'MarianMTModel', 'MBartForConditionalGeneration', 'MT5ForConditionalGeneration', 'MvpForConditionalGeneration', 'NllbMoeForConditionalGeneration', 'PegasusForConditionalGeneration', 'PegasusXForConditionalGeneration', 'PLBartForConditionalGeneration', 'ProphetNetForConditionalGeneration', 'Qwen2AudioForConditionalGeneration', 'SeamlessM4TForTextToText', 'SeamlessM4Tv2ForTextToText', 'SwitchTransformersForConditionalGeneration', 'T5ForConditionalGeneration', 'UMT5ForConditionalGeneration', 'XLMProphetNetForConditionalGeneration'].
# Row 1 - Original SOAP Note:
#  Subjective: The patient reports painless blurry vision in the right eye for one week, along with intermittent fever, headaches, body aches, and a non-pruritic maculopapular rash on both lower limbs present for six months. There is no associated neck stiffness, nausea, vomiting, Raynauds phenomenon, oral ulcers, chest pain, dyspnea, abdominal pain, or photosensitivity. Past medical history includes occasional episodes of left knee and testicle swelling but no known exposure to toxins or unhealthy lifestyle practices such as smoking, alcohol consumption, or illegal drugs. Currently employed as a flooring installer.
# Objective: Vital signs within normal limits. Physical examination revealed bilateral papilledema and optic nerve erythema more pronounced in the right eye compared to the left, accompanied by a right inferior nasal quadrant visual field deficit and a relative afferent pupillary defect. Muscle tone and deep tendon reflexes were unremarkable; sensory testing indicated intact responses to light touch, pin prick, vibratory stimuli, and proprioceptive input. Maculopapular rashes noted bilaterally over the lower limb areas. Laboratory studies demonstrated microcytic anemia with decreased hemoglobin levels 11.6 gmdl, hematocrit 35.3, MCV 76.9 fl, elevated ESR 33mmhr, CRP 13.3mgdl, and low serum sodium concentration 133mml.
# Assessment: Differential diagnosis considerations include autoimmune disorders, vasculitis, infection, malignancy, and neurologic conditions affecting the eyes. Further investigations required to establish definitive etiology.
# Plan: Additional laboratory analyses including complete blood count, comprehensive metabolic panel, rheumatologic serologies, urine analysis, cerebrospinal fluid evaluation, and imaging studies will be conducted to aid in determining the underlying pathology causing these presenting complaints. Consultation with relevant specialists e.g., ophthalmologist, rheumatology, etc. may be sought based on initial diagnostic impressions. Close monitoring of symptoms and ongoing communication regarding management strategies will continue until a final diagnosis is established.
#
# Row 1 - Summarized and Explainable Report:
#
# You are a medical assistant. Your task is to take a SOAP (Subjective, Objective, Assessment, Plan) report and generate a summarized, easy-to-understand explanation. The output should be clear and accessible to anyone without a medical background, avoiding jargon unless fully explained.
#
# SOAP Report:
# Subjective: The patient reports painless blurry vision in the right eye for one week, along with intermittent fever, headaches, body aches, and a non-pruritic maculopapular rash on both lower limbs present for six months. There is no associated neck stiffness, nausea, vomiting, Raynauds phenomenon, oral ulcers, chest pain, dyspnea, abdominal pain, or photosensitivity. Past medical history includes occasional episodes of left knee and testicle swelling but no known exposure to toxins or unhealthy lifestyle practices such as smoking, alcohol consumption, or illegal drugs. Currently employed as a flooring installer.
# Objective: Vital signs within normal limits. Physical examination revealed bilateral papilledema and optic nerve erythema more pronounced in the right eye compared to the left, accompanied by a right inferior nasal quadrant visual field deficit and a relative afferent pupillary defect. Muscle tone and deep tendon reflexes were unremarkable; sensory testing indicated intact responses to light touch, pin prick, vibratory stimuli, and proprioceptive input. Maculopapular rashes noted bilaterally over the lower limb areas. Laboratory studies demonstrated microcytic anemia with decreased hemoglobin levels 11.6 gmdl, hematocrit 35.3, MCV 76.9 fl, elevated ESR 33mmhr, CRP 13.3mgdl, and low serum sodium concentration 133mml.
# Assessment: Differential diagnosis considerations include autoimmune disorders, vasculitis, infection, malignancy, and neurologic conditions affecting the eyes. Further investigations required to establish definitive etiology.
# Plan: Additional laboratory analyses including complete blood count, comprehensive metabolic panel, rheumatologic serologies, urine analysis, cerebrospinal fluid evaluation, and imaging studies will be conducted to aid in determining the underlying pathology causing these presenting complaints. Consultation with relevant specialists e.g., ophthalmologist, rheumatology, etc. may be sought based on initial diagnostic impressions. Close monitoring of symptoms and ongoing communication regarding management strategies will continue until a final diagnosis is established.
#
# Summarized and Explainable Report:
# The patient reports painless blurry vision in the right eye
# ====================================================================================================
#
# Row 2 - Original SOAP Note:
#  Subjective: The patient is a 7-year-old male with congenital bilateral sensorineural deafness who previously underwent a failed right cochlear implantation. He reports no discomfort during recent magnetic resonance imaging mri procedures where his airway was maintained with a cuffed endotracheal tube ett.
# Objective: A size 5.5 mm internal diameter uncuffed ett was utilized for securing the patients airway during the mri scan. Intraoperative neurophysiological monitoring including brainstem auditory sensory evoked potentials, brainstem mapping of cranial nerve cn ix x xi xii and their motor nuclei, and corticobulbar tract motor-evoked potential mep will be performed during the upcoming surgical intervention.
# Assessment: The planned surgery involves inserting an auditory brainstem implant abi due to previous failure of a cochlear implant. Neurological monitoring techniques such as brainstem auditory sensory evoked potentials, brainstem mapping of cn ix x xi xii, and corticobulbar tract meps will aid in ensuring proper functioning of these vital structures during the operation.
# Plan: On the day of surgery, the anesthesia team will place leads for cn ix x xi xii prior to intubating the patient again using a specially-prepared uncuffed ett equipped with laryngeal electrodes. Tiva total intravenous anesthesia consisting of propofol and remifentanil will be administered to maintain unconsciousness and analgesia throughout the procedure. Post-operative care and close monitoring will focus on assessing the success of the abi implant and managing any complications related to the surgery.
#
# Row 2 - Summarized and Explainable Report:
#
# You are a medical assistant. Your task is to take a SOAP (Subjective, Objective, Assessment, Plan) report and generate a summarized, easy-to-understand explanation. The output should be clear and accessible to anyone without a medical background, avoiding jargon unless fully explained.
#
# SOAP Report:
# Subjective: The patient is a 7-year-old male with congenital bilateral sensorineural deafness who previously underwent a failed right cochlear implantation. He reports no discomfort during recent magnetic resonance imaging mri procedures where his airway was maintained with a cuffed endotracheal tube ett.
# Objective: A size 5.5 mm internal diameter uncuffed ett was utilized for securing the patients airway during the mri scan. Intraoperative neurophysiological monitoring including brainstem auditory sensory evoked potentials, brainstem mapping of cranial nerve cn ix x xi xii and their motor nuclei, and corticobulbar tract motor-evoked potential mep will be performed during the upcoming surgical intervention.
# Assessment: The planned surgery involves inserting an auditory brainstem implant abi due to previous failure of a cochlear implant. Neurological monitoring techniques such as brainstem auditory sensory evoked potentials, brainstem mapping of cn ix x xi xii, and corticobulbar tract meps will aid in ensuring proper functioning of these vital structures during the operation.
# Plan: On the day of surgery, the anesthesia team will place leads for cn ix x xi xii prior to intubating the patient again using a specially-prepared uncuffed ett equipped with laryngeal electrodes. Tiva total intravenous anesthesia consisting of propofol and remifentanil will be administered to maintain unconsciousness and analgesia throughout the procedure. Post-operative care and close monitoring will focus on assessing the success of the abi implant and managing any complications related to the surgery.
#
# Summarized and Explainable Report:
# The patient is a 7-year-old male with congenital bilateral sensorineural deafness who previously underwent a failed right cochlear implantation. He reports no discomfort during recent magnetic resonance imaging procedures where his airway was maintained with a cuffed endotracheal tube. A size 5.5 mm internal diameter uncuffed endotracheal tube was utilized for securing the patient's airway during the MRI scan. Intraoperative neurophysiological monitoring including brainstem auditory sensory evoked potentials, brainstem mapping of cranial nerve IX, X,
# ====================================================================================================
#
# Row 3 - Original SOAP Note:
#  Subjective: The patient reports having undergone an ultrasound in April 2017 revealing a single thyroid nodule in the left lobe. Post-operative evaluation shows no complications during the initial period.
# Objective: Ultrasound imaging confirmed a single thyroid nodule measuring 1cm in the left lobe. Biochemical testing indicated elevated calcitonin levels at 40ngml, peaking at 1420ngml upon stimulation. Histopathology identified medullary thyroid carcinoma MTC within the excised tissue, along with focal areas of c-cell hyperplasia. No evidence of metastasis was detected in the lymph nodes examined.
# Assessment: Medullary thyroid carcinoma MTC diagnosed based on histologic features and elevated calcitonin levels. Initial post-surgical assessment reveals favorable outcomes without significant complications. Further surveillance required due to residual c-cell hyperplasia and potential recurrence risk.
# Plan: Continued close monitoring through routine check-ups and additional screenings as needed. Follow up with endocrinologist to manage calcitonin levels and monitor for possible recurrences.
#
# Row 3 - Summarized and Explainable Report:
#
# You are a medical assistant. Your task is to take a SOAP (Subjective, Objective, Assessment, Plan) report and generate a summarized, easy-to-understand explanation. The output should be clear and accessible to anyone without a medical background, avoiding jargon unless fully explained.
#
# SOAP Report:
# Subjective: The patient reports having undergone an ultrasound in April 2017 revealing a single thyroid nodule in the left lobe. Post-operative evaluation shows no complications during the initial period.
# Objective: Ultrasound imaging confirmed a single thyroid nodule measuring 1cm in the left lobe. Biochemical testing indicated elevated calcitonin levels at 40ngml, peaking at 1420ngml upon stimulation. Histopathology identified medullary thyroid carcinoma MTC within the excised tissue, along with focal areas of c-cell hyperplasia. No evidence of metastasis was detected in the lymph nodes examined.
# Assessment: Medullary thyroid carcinoma MTC diagnosed based on histologic features and elevated calcitonin levels. Initial post-surgical assessment reveals favorable outcomes without significant complications. Further surveillance required due to residual c-cell hyperplasia and potential recurrence risk.
# Plan: Continued close monitoring through routine check-ups and additional screenings as needed. Follow up with endocrinologist to manage calcitonin levels and monitor for possible recurrences.
#
# Summarized and Explainable Report:
# The patient underwent an ultrasound in April 2017 which revealed a single thyroid nodule in the left lobe. Post-operative evaluation showed no complications during the initial period. Ultrasound imaging confirmed a single thyroid nodule measuring 1cm in the left lobe. Biochemical testing indicated elevated calcitonin levels at 40ngml, peaking at 1420ngml upon stimulation. Histopathology identified medullary thyroid carcinoma MTC within the excised tissue, along with focal areas of c-cell hyperplasia. No evidence of metastasis was detected in the lymph nodes examined. Medullary thyroid carcinoma MTC was diagnosed based on histologic features and elevated calcitonin levels. Initial post-surgical assessment revealed favorable outcomes without significant complications. Further surveillance was required due to residual c-cell hyperplasia and potential recurrence risk. Continued close monitoring through routine check-ups and additional screenings as needed. Follow up with endocrinologist to manage calcitonin levels and monitor for possible recurrences.
# ====================================================================================================
#
# Row 4 - Original SOAP Note:
#  Subjective: patient reports experiencing a progressive headache, nausea, and vomiting over one week; additionally noted right-sided weakness, ptosis, and diplopia beginning around the same time period. Initially experienced acute consciousness disturbances which resolved post-hospitalization.
# Objective: initial presentation included a GCS score of E3VAM5 upon admission. subsequent diagnostic testing indicated an enhanced brain tumor with necrotic cystic changes localized within the left temporal lobe extending into surrounding structures including the left basal ganglia and periventricular regions resulting in significant perifocal edema and midline shifts. histopathology confirmed classical glioblastoma multiforme gbm characterized by pleomorphic cellular morphology, hyperchromasia, prominent astrocytes, vascular proliferations, and areas of necrosis. post-operative treatments include radiation therapy and chemotherapeutic agents such as temozolomide administered for approximately six months. recent follow-ups indicate progression of disease evidenced through additional mass formations on mri scans prompting two additional surgical resections revealing mixed pathologies suggestive of both primary central nervous system lymphomas pcsnl and high-grade gliomas hgg exhibiting positive markers for idh1, p53, mgmt negative, and cd56 expression among others.
# Assessment: current assessment indicates recurrent malignant neoplasm involving multiple CNS sites previously diagnosed as gbms now showing evidence of pcsnls and hgg. ongoing surveillance required due to aggressive nature of malignancy and potential for metastasis despite prior interventions.
# Plan: continued monitoring via regular clinic visits necessary to assess efficacy of existing therapies and identify emerging complications associated with advanced stage cancerous growths. multidisciplinary team approach recommended to optimize management strategies based on evolving pathological characteristics.
#
# Row 4 - Summarized and Explainable Report:
#
# You are a medical assistant. Your task is to take a SOAP (Subjective, Objective, Assessment, Plan) report and generate a summarized, easy-to-understand explanation. The output should be clear and accessible to anyone without a medical background, avoiding jargon unless fully explained.
#
# SOAP Report:
# Subjective: patient reports experiencing a progressive headache, nausea, and vomiting over one week; additionally noted right-sided weakness, ptosis, and diplopia beginning around the same time period. Initially experienced acute consciousness disturbances which resolved post-hospitalization.
# Objective: initial presentation included a GCS score of E3VAM5 upon admission. subsequent diagnostic testing indicated an enhanced brain tumor with necrotic cystic changes localized within the left temporal lobe extending into surrounding structures including the left basal ganglia and periventricular regions resulting in significant perifocal edema and midline shifts. histopathology confirmed classical glioblastoma multiforme gbm characterized by pleomorphic cellular morphology, hyperchromasia, prominent astrocytes, vascular proliferations, and areas of necrosis. post-operative treatments include radiation therapy and chemotherapeutic agents such as temozolomide administered for approximately six months. recent follow-ups indicate progression of disease evidenced through additional mass formations on mri scans prompting two additional surgical resections revealing mixed pathologies suggestive of both primary central nervous system lymphomas pcsnl and high-grade gliomas hgg exhibiting positive markers for idh1, p53, mgmt negative, and cd56 expression among others.
# Assessment: current assessment indicates recurrent malignant neoplasm involving multiple CNS sites previously diagnosed as gbms now showing evidence of pcsnls and hgg. ongoing surveillance required due to aggressive nature of malignancy and potential for metastasis despite prior interventions.
# Plan: continued monitoring via regular clinic visits necessary to assess efficacy of existing therapies and identify emerging complications associated with advanced stage cancerous growths. multidisciplinary team approach recommended to optimize management strategies based on evolving pathological characteristics.
#
# Summarized and Explainable Report:
# A 45-year-old male presented with a progressive headache, nausea, and vomiting over one week. Additionally, he reported right-sided weakness, ptosis, and diplopia beginning around the same time period. Initially, he experienced acute consciousness disturbances which resolved post-hospitalization. Upon admission, his Glasgow Coma Scale score was 3/15. Diagnostic testing revealed an enhanced brain tumor with necrotic cystic changes localized within the
# ====================================================================================================
#
# Row 5 - Original SOAP Note:
#  Subjective: patient reports severe abdominal pain as the primary symptom, which worsened over several weeks prior to admission. Pain is described as persistent and debilitating despite treatment interventions.
# Objective: initial diagnosis upon admission included severe acute pancreatitis. vital signs showed elevated blood pressure during periods of withdrawal symptoms. laboratory results not provided due to lack of documentation.
# Assessment: patient diagnosed with recurrent episodes of severe acute pancreatitis post-liver transplant. current management includes continued use of opioids to manage pain associated with pancreatitis.
# Plan: ongoing management involves adjusting dosages of analgesics based on subjective feedback regarding pain levels. additional treatments include administration of antibiotics, fluids, and pancreatic enzymes. future plans involve gradual reduction of opioid doses through alternative delivery methods such as patches to minimize risk of withdrawal symptoms. close monitoring required to assess effectiveness of treatment strategies and adjust accordingly.
#
# Row 5 - Summarized and Explainable Report:
#
# You are a medical assistant. Your task is to take a SOAP (Subjective, Objective, Assessment, Plan) report and generate a summarized, easy-to-understand explanation. The output should be clear and accessible to anyone without a medical background, avoiding jargon unless fully explained.
#
# SOAP Report:
# Subjective: patient reports severe abdominal pain as the primary symptom, which worsened over several weeks prior to admission. Pain is described as persistent and debilitating despite treatment interventions.
# Objective: initial diagnosis upon admission included severe acute pancreatitis. vital signs showed elevated blood pressure during periods of withdrawal symptoms. laboratory results not provided due to lack of documentation.
# Assessment: patient diagnosed with recurrent episodes of severe acute pancreatitis post-liver transplant. current management includes continued use of opioids to manage pain associated with pancreatitis.
# Plan: ongoing management involves adjusting dosages of analgesics based on subjective feedback regarding pain levels. additional treatments include administration of antibiotics, fluids, and pancreatic enzymes. future plans involve gradual reduction of opioid doses through alternative delivery methods such as patches to minimize risk of withdrawal symptoms. close monitoring required to assess effectiveness of treatment strategies and adjust accordingly.
#
# Summarized and Explainable Report:
# Patient presents with severe abdominal pain, which has persisted despite previous treatments. Initial diagnosis upon admission was severe acute pancreatitis. However, due to lack of documentation, laboratory results were unavailable. Current management involves ongoing use of opioids to manage pain associated with pancreatitis. Additional treatments include administration of antibiotics, fluids, and pancreatic enzymes. Future plans involve gradual reduction of opioid doses through alternative delivery methods such as patches to minimize risk of withdrawal symptoms. Close monitoring is necessary to assess the effectiveness of treatment strategies and adjust them accordingly.
# ====================================================================================================

# %%
# Load a summarization model (BART is well-suited for this task)
model_name = "facebook/bart-large-cnn"
generator = pipeline("summarization", model=model_name)

# Function to create a prompt for summarization
def create_prompt(soap_note):
    return f"""
Summarize the following SOAP (Subjective, Objective, Assessment, Plan) report into a concise, easy-to-understand explanation for someone without a medical background. Avoid technical terms unless they’re explained simply. Focus on what the patient feels, what the doctor found, what might be wrong, and what will happen next.

SOAP Report:
{soap_note}

Summarized and Explainable Report:
"""

# Function to generate the summary
def generate_summary(soap_note):
    try:
        # Use the SOAP note directly as input for summarization, with a custom prompt
        response = generator(soap_note, max_length=150, min_length=50, do_sample=False)
        summary = response[0]['summary_text']
        # Post-process to ensure it’s clear and fits the "explainable" goal
        return summary.replace("SOAP", "").strip()
    except Exception as e:
        return f"Error generating summary: {str(e)}"

# Read the CSV file
csv_file_path = '/content/output.csv'  # Replace with your actual CSV file path
try:
    df = pd.read_csv(csv_file_path)
    df = df.head(5)  # Limit to first 5 rows for testing
except FileNotFoundError:
    print(f"Error: File '{csv_file_path}' not found.")
    exit()

# Ensure the column name matches your CSV
if 'SOAP' not in df.columns:
    raise ValueError("The CSV file must contain a 'SOAP' column")

# List to store results
results = []

# Process each row
for index, row in df.iterrows():
    soap_note = row['SOAP']
    simplified = generate_summary(soap_note)

    # Store results
    results.append({"Row": index + 1, "Original SOAP Note": soap_note, "Simplified Report": simplified})

    # Print with improved formatting
    print(f"\n{'*' * 50} Row {index + 1} {'*' * 50}")
    print(f"Original Note:\n{soap_note}\n")
    print(f"Simplified Explanation:\n{simplified}")
    print(f"{'*' * 110}")

# Save results to a new CSV file
output_df = pd.DataFrame(results)
output_df.to_csv('simplified_soap_reports.csv', index=False)
print("\nResults saved to 'simplified_soap_reports.csv'")
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# ************************************************** Row 1 **************************************************
# Original Note:
# Subjective: The patient reports painless blurry vision in the right eye for one week, along with intermittent fever, headaches, body aches, and a non-pruritic maculopapular rash on both lower limbs present for six months. There is no associated neck stiffness, nausea, vomiting, Raynauds phenomenon, oral ulcers, chest pain, dyspnea, abdominal pain, or photosensitivity. Past medical history includes occasional episodes of left knee and testicle swelling but no known exposure to toxins or unhealthy lifestyle practices such as smoking, alcohol consumption, or illegal drugs. Currently employed as a flooring installer.
# Objective: Vital signs within normal limits. Physical examination revealed bilateral papilledema and optic nerve erythema more pronounced in the right eye compared to the left, accompanied by a right inferior nasal quadrant visual field deficit and a relative afferent pupillary defect. Muscle tone and deep tendon reflexes were unremarkable; sensory testing indicated intact responses to light touch, pin prick, vibratory stimuli, and proprioceptive input. Maculopapular rashes noted bilaterally over the lower limb areas. Laboratory studies demonstrated microcytic anemia with decreased hemoglobin levels 11.6 gmdl, hematocrit 35.3, MCV 76.9 fl, elevated ESR 33mmhr, CRP 13.3mgdl, and low serum sodium concentration 133mml.
# Assessment: Differential diagnosis considerations include autoimmune disorders, vasculitis, infection, malignancy, and neurologic conditions affecting the eyes. Further investigations required to establish definitive etiology.
# Plan: Additional laboratory analyses including complete blood count, comprehensive metabolic panel, rheumatologic serologies, urine analysis, cerebrospinal fluid evaluation, and imaging studies will be conducted to aid in determining the underlying pathology causing these presenting complaints. Consultation with relevant specialists e.g., ophthalmologist, rheumatology, etc. may be sought based on initial diagnostic impressions. Close monitoring of symptoms and ongoing communication regarding management strategies will continue until a final diagnosis is established.
#
# Simplified Explanation:
# The patient reports painless blurry vision in the right eye for one week, along with intermittent fever, headaches, body aches, and a non-pruritic maculopapular rash on both lower limbs present for six months. There is no associated neck stiffness, nausea, vomiting, Raynauds phenomenon, oral ulcers, chest pain, dyspnea, abdominal pain, or photosensitivity.
# **************************************************************************************************************
#
# ************************************************** Row 2 **************************************************
# Original Note:
# Subjective: The patient is a 7-year-old male with congenital bilateral sensorineural deafness who previously underwent a failed right cochlear implantation. He reports no discomfort during recent magnetic resonance imaging mri procedures where his airway was maintained with a cuffed endotracheal tube ett.
# Objective: A size 5.5 mm internal diameter uncuffed ett was utilized for securing the patients airway during the mri scan. Intraoperative neurophysiological monitoring including brainstem auditory sensory evoked potentials, brainstem mapping of cranial nerve cn ix x xi xii and their motor nuclei, and corticobulbar tract motor-evoked potential mep will be performed during the upcoming surgical intervention.
# Assessment: The planned surgery involves inserting an auditory brainstem implant abi due to previous failure of a cochlear implant. Neurological monitoring techniques such as brainstem auditory sensory evoked potentials, brainstem mapping of cn ix x xi xii, and corticobulbar tract meps will aid in ensuring proper functioning of these vital structures during the operation.
# Plan: On the day of surgery, the anesthesia team will place leads for cn ix x xi xii prior to intubating the patient again using a specially-prepared uncuffed ett equipped with laryngeal electrodes. Tiva total intravenous anesthesia consisting of propofol and remifentanil will be administered to maintain unconsciousness and analgesia throughout the procedure. Post-operative care and close monitoring will focus on assessing the success of the abi implant and managing any complications related to the surgery.
#
# Simplified Explanation:
# The patient is a 7-year-old male with congenital bilateral sensorineural deafness who previously underwent a failed right cochlear implantation. He reports no discomfort during recent magnetic resonance imaging mri procedures where his airway was maintained with a cuffed endotracheal tube ett.
# **************************************************************************************************************
#
# ************************************************** Row 3 **************************************************
# Original Note:
# Subjective: The patient reports having undergone an ultrasound in April 2017 revealing a single thyroid nodule in the left lobe. Post-operative evaluation shows no complications during the initial period.
# Objective: Ultrasound imaging confirmed a single thyroid nodule measuring 1cm in the left lobe. Biochemical testing indicated elevated calcitonin levels at 40ngml, peaking at 1420ngml upon stimulation. Histopathology identified medullary thyroid carcinoma MTC within the excised tissue, along with focal areas of c-cell hyperplasia. No evidence of metastasis was detected in the lymph nodes examined.
# Assessment: Medullary thyroid carcinoma MTC diagnosed based on histologic features and elevated calcitonin levels. Initial post-surgical assessment reveals favorable outcomes without significant complications. Further surveillance required due to residual c-cell hyperplasia and potential recurrence risk.
# Plan: Continued close monitoring through routine check-ups and additional screenings as needed. Follow up with endocrinologist to manage calcitonin levels and monitor for possible recurrences.
#
# Simplified Explanation:
# Ultrasound imaging confirmed a single thyroid nodule measuring 1cm in the left lobe. Histopathology identified medullary thyroid carcinoma MTC within the excised tissue. Further surveillance required due to residual c-cell hyperplasia and potential recurrence risk.
# **************************************************************************************************************
#
# ************************************************** Row 4 **************************************************
# Original Note:
# Subjective: patient reports experiencing a progressive headache, nausea, and vomiting over one week; additionally noted right-sided weakness, ptosis, and diplopia beginning around the same time period. Initially experienced acute consciousness disturbances which resolved post-hospitalization.
# Objective: initial presentation included a GCS score of E3VAM5 upon admission. subsequent diagnostic testing indicated an enhanced brain tumor with necrotic cystic changes localized within the left temporal lobe extending into surrounding structures including the left basal ganglia and periventricular regions resulting in significant perifocal edema and midline shifts. histopathology confirmed classical glioblastoma multiforme gbm characterized by pleomorphic cellular morphology, hyperchromasia, prominent astrocytes, vascular proliferations, and areas of necrosis. post-operative treatments include radiation therapy and chemotherapeutic agents such as temozolomide administered for approximately six months. recent follow-ups indicate progression of disease evidenced through additional mass formations on mri scans prompting two additional surgical resections revealing mixed pathologies suggestive of both primary central nervous system lymphomas pcsnl and high-grade gliomas hgg exhibiting positive markers for idh1, p53, mgmt negative, and cd56 expression among others.
# Assessment: current assessment indicates recurrent malignant neoplasm involving multiple CNS sites previously diagnosed as gbms now showing evidence of pcsnls and hgg. ongoing surveillance required due to aggressive nature of malignancy and potential for metastasis despite prior interventions.
# Plan: continued monitoring via regular clinic visits necessary to assess efficacy of existing therapies and identify emerging complications associated with advanced stage cancerous growths. multidisciplinary team approach recommended to optimize management strategies based on evolving pathological characteristics.
#
# Simplified Explanation:
# Initial presentation included a GCS score of E3VAM5 upon admission. histopathology confirmed classical glioblastoma multiforme gbm characterized by pleomorphic cellular morphology, hyperchromasia, prominent astrocytes, vascular proliferations, and areas of necrosis. post-operative treatments include radiation therapy and chemotherapeutic agents.
# **************************************************************************************************************
#
# ************************************************** Row 5 **************************************************
# Original Note:
# Subjective: patient reports severe abdominal pain as the primary symptom, which worsened over several weeks prior to admission. Pain is described as persistent and debilitating despite treatment interventions.
# Objective: initial diagnosis upon admission included severe acute pancreatitis. vital signs showed elevated blood pressure during periods of withdrawal symptoms. laboratory results not provided due to lack of documentation.
# Assessment: patient diagnosed with recurrent episodes of severe acute pancreatitis post-liver transplant. current management includes continued use of opioids to manage pain associated with pancreatitis.
# Plan: ongoing management involves adjusting dosages of analgesics based on subjective feedback regarding pain levels. additional treatments include administration of antibiotics, fluids, and pancreatic enzymes. future plans involve gradual reduction of opioid doses through alternative delivery methods such as patches to minimize risk of withdrawal symptoms. close monitoring required to assess effectiveness of treatment strategies and adjust accordingly.
#
# Simplified Explanation:
# Pain is described as persistent and debilitating despite treatment interventions. Initial diagnosis upon admission included severe acute pancreatitis. future plans involve gradual reduction of opioid doses through alternative delivery methods such as patches to minimize risk of withdrawal symptoms. close monitoring required to assess effectiveness of treatment strategies.
# **************************************************************************************************************
#
# Results saved to 'simplified_soap_reports.csv'
